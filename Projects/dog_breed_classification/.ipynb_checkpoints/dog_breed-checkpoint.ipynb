# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

  
from sklearn.preprocessing import LabelEncoder 
from sklearn.model_selection import train_test_split 
  
import cv2 
import tensorflow as tf 
from tensorflow import keras 
from keras import layers 
from functools import partial 

  
import warnings 
warnings.filterwarnings('ignore') 
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# 2023-12-21 17:26:37.108134: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 17:26:37.108179: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 17:26:37.109555: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 17:26:37.120532: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-21 17:26:38.421415: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from zipfile import ZipFile 
data_path = 'dog-breed-identification.zip'
  
with ZipFile(data_path, 'r') as zip: 
    zip.extractall() 
    print('The data set has been extracted.')
# Out:
# The data set has been extracted.

# %%
df = pd.read_csv('labels.csv') 
df.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
df.shape
# Out:
# (10222, 2)

# %%
print('Number of Unique Breeds are :',df['breed'].nunique())
# Out:
# Number of Unique Breeds are : 120

# %%
plt.figure(figsize=(10, 5)) 
df['breed'].value_counts().plot.bar() 
plt.axis('off') 
plt.show()

# %%
df['filepath'] = 'train/' + df['id'] + '.jpg'
df.head()
# Out:
#                                  id             breed  \
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever
#
#                                      filepath
# 0  train/000bec180eb18c7604dcecc8fe0dba07.jpg
# 1  train/001513dfcb2ffafc82cccf4d8bbaba97.jpg
# 2  train/001cdf01b096e06d78e9e5112d419397.jpg
# 3  train/00214f311d5d2247d5dfe4fe24b2303d.jpg
# 4  train/0021f9ceb3235effd7fcde7f7538ed62.jpg

# %%
plt.subplots(figsize=(10, 10)) 
for i in range(12): 
    plt.subplot(4, 3, i+1) 
  
    # Selecting a random image 
    # index from the dataframe. 
    k = np.random.randint(0, len(df)) 
    img = cv2.imread(df.loc[k, 'filepath']) 
    plt.imshow(img) 
    plt.title(df.loc[k, 'breed']) 
    plt.axis('off') 
plt.show()

# %%
le = LabelEncoder() 
df['breed'] = le.fit_transform(df['breed']) 
df.head()
# Out:
#                                  id  breed  \
# 0  000bec180eb18c7604dcecc8fe0dba07     19
# 1  001513dfcb2ffafc82cccf4d8bbaba97     37
# 2  001cdf01b096e06d78e9e5112d419397     85
# 3  00214f311d5d2247d5dfe4fe24b2303d     15
# 4  0021f9ceb3235effd7fcde7f7538ed62     49
#
#                                      filepath
# 0  train/000bec180eb18c7604dcecc8fe0dba07.jpg
# 1  train/001513dfcb2ffafc82cccf4d8bbaba97.jpg
# 2  train/001cdf01b096e06d78e9e5112d419397.jpg
# 3  train/00214f311d5d2247d5dfe4fe24b2303d.jpg
# 4  train/0021f9ceb3235effd7fcde7f7538ed62.jpg

# %%
features = df['filepath'] 
target = df['breed'] 
  
X_train, X_val,Y_train, Y_val = train_test_split(features, target, test_size=0.15, random_state=10) 
  
X_train.shape, X_val.shape
# Out:
# ((8688,), (1534,))

# %%
import albumentations as A 
  
transforms_train = A.Compose([ 
    A.VerticalFlip(p=0.2), 
    A.HorizontalFlip(p=0.7), 
    A.CoarseDropout(p=0.5), 
    A.RandomGamma(p=0.5), 
    A.RandomBrightnessContrast(p=1) 
])

# %%
img = cv2.imread('train/0a1f8334a9f583cac009dc033c681e47.jpg') 
plt.imshow(img) 
plt.show()

# %%
augments = [A.VerticalFlip(p=1), A.HorizontalFlip(p=1), 
            A.CoarseDropout(p=1), A.CLAHE(p=1)] 
  
plt.subplots(figsize=(10, 10)) 
for i, aug in enumerate(augments): 
    plt.subplot(2, 2, i+1) 
    aug_img = aug(image=img)['image'] 
    plt.imshow(aug_img) 
plt.show()

# %%
def aug_fn(img): 
	aug_data = transforms_train(image=img) 
	aug_img = aug_data['image'] 

	return aug_img 


@tf.function 
def process_data(img, label): 
	aug_img = tf.numpy_function(aug_fn, 
								[img], 
								Tout=tf.float32) 

	return img, label 


def decode_image(filepath, label=None): 

	img = tf.io.read_file(filepath) 
	img = tf.image.decode_jpeg(img) 
	img = tf.image.resize(img, [128, 128]) 
	img = tf.cast(img, tf.float32) / 255.0

	if label == None: 
		return img 

	return img, tf.one_hot(indices=label, 
						depth=120, 
						dtype=tf.float32)

# %%
train_ds = ( 
	tf.data.Dataset 
	.from_tensor_slices((X_train, Y_train)) 
	.map(decode_image, num_parallel_calls=AUTO) 
	.map(partial(process_data), num_parallel_calls=AUTO) 
	.batch(32) 
	.prefetch(AUTO) 
) 

val_ds = ( 
	tf.data.Dataset 
	.from_tensor_slices((X_val, Y_val)) 
	.map(decode_image, num_parallel_calls=AUTO) 
	.batch(32) 
	.prefetch(AUTO) 
)

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3 
  
pre_trained_model = InceptionV3( 
    input_shape=(128, 128, 3), 
    weights='imagenet', 
    include_top=False
)

# %%
len(pre_trained_model.layers)
# Out:
# 311

# %%
for layer in pre_trained_model.layers: 
  layer.trainable = False
  
last_layer = pre_trained_model.get_layer('mixed7') 
print('last layer output shape: ', last_layer.output_shape) 
last_output = last_layer.output
# Out:
# last layer output shape:  (None, 6, 6, 768)

# %%
 #Model Architecture 
x = layers.Flatten()(last_output) 
x = layers.Dense(256, activation='relu')(x) 
x = layers.BatchNormalization()(x) 
x = layers.Dense(256, activation='relu')(x) 
x = layers.Dropout(0.3)(x) 
x = layers.BatchNormalization()(x) 
output = layers.Dense(120, activation='softmax')(x) 
  
model = keras.Model(pre_trained_model.input, output) 
  
# Model Compilation 
model.compile( 
    optimizer='adam', 
    loss=keras.losses.CategoricalCrossentropy(from_logits=True), 
    metrics=['AUC'] 
)

# %%
history = model.fit(train_ds,validation_data=val_ds, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 272/272 [==============================] - 131s 460ms/step - loss: 3.7087 - auc: 0.8264 - val_loss: 2.5273 - val_auc: 0.9388
# Epoch 2/50
# 272/272 [==============================] - 135s 495ms/step - loss: 2.0103 - auc: 0.9700 - val_loss: 2.3852 - val_auc: 0.9405
# Epoch 3/50
# 272/272 [==============================] - 117s 430ms/step - loss: 1.0297 - auc: 0.9939 - val_loss: 2.4202 - val_auc: 0.9275
# Epoch 4/50
# 272/272 [==============================] - 108s 398ms/step - loss: 0.4040 - auc: 0.9995 - val_loss: 2.5336 - val_auc: 0.9096
# Epoch 5/50
# 272/272 [==============================] - 108s 396ms/step - loss: 0.1718 - auc: 0.9998 - val_loss: 2.5211 - val_auc: 0.9069
# Epoch 6/50
# 272/272 [==============================] - 109s 399ms/step - loss: 0.0912 - auc: 0.9999 - val_loss: 2.5399 - val_auc: 0.9056
# Epoch 7/50
# 272/272 [==============================] - 109s 399ms/step - loss: 0.0651 - auc: 0.9999 - val_loss: 2.6571 - val_auc: 0.8947
# Epoch 8/50
# 272/272 [==============================] - 120s 440ms/step - loss: 0.0510 - auc: 0.9998 - val_loss: 2.7711 - val_auc: 0.8905
# Epoch 9/50
# 272/272 [==============================] - 114s 418ms/step - loss: 0.0468 - auc: 1.0000 - val_loss: 2.8759 - val_auc: 0.8828
# Epoch 10/50
# 272/272 [==============================] - 141s 519ms/step - loss: 0.0787 - auc: 0.9999 - val_loss: 3.4491 - val_auc: 0.8353
# Epoch 11/50
# 272/272 [==============================] - 140s 516ms/step - loss: 0.2527 - auc: 0.9990 - val_loss: 3.5359 - val_auc: 0.8424
# Epoch 12/50
# 272/272 [==============================] - 129s 475ms/step - loss: 0.2721 - auc: 0.9983 - val_loss: 3.3421 - val_auc: 0.8549
# Epoch 13/50
# 272/272 [==============================] - 125s 459ms/step - loss: 0.1452 - auc: 0.9997 - val_loss: 3.2409 - val_auc: 0.8585
# Epoch 14/50
# 272/272 [==============================] - 127s 468ms/step - loss: 0.0588 - auc: 0.9999 - val_loss: 3.2319 - val_auc: 0.8550
# Epoch 15/50
# 272/272 [==============================] - 120s 440ms/step - loss: 0.0337 - auc: 1.0000 - val_loss: 3.2418 - val_auc: 0.8597
# Epoch 16/50
# 272/272 [==============================] - 124s 456ms/step - loss: 0.0277 - auc: 1.0000 - val_loss: 3.2952 - val_auc: 0.8502
# Epoch 17/50
# 272/272 [==============================] - 118s 435ms/step - loss: 0.0259 - auc: 0.9999 - val_loss: 3.3999 - val_auc: 0.8462
# Epoch 18/50
# 272/272 [==============================] - 114s 419ms/step - loss: 0.0318 - auc: 1.0000 - val_loss: 3.4754 - val_auc: 0.8443
# Epoch 19/50
# 272/272 [==============================] - 116s 427ms/step - loss: 0.0636 - auc: 0.9996 - val_loss: 3.7573 - val_auc: 0.8262
# Epoch 20/50
# 272/272 [==============================] - 122s 449ms/step - loss: 0.1296 - auc: 0.9993 - val_loss: 4.0041 - val_auc: 0.8250
# Epoch 21/50
# 272/272 [==============================] - 122s 450ms/step - loss: 0.1362 - auc: 0.9993 - val_loss: 4.0644 - val_auc: 0.8193
# Epoch 22/50
# 272/272 [==============================] - 122s 449ms/step - loss: 0.0906 - auc: 0.9995 - val_loss: 3.8455 - val_auc: 0.8287
# Epoch 23/50
# 272/272 [==============================] - 122s 448ms/step - loss: 0.0649 - auc: 0.9998 - val_loss: 3.9733 - val_auc: 0.8237
# Epoch 24/50
# 272/272 [==============================] - 121s 445ms/step - loss: 0.0534 - auc: 0.9997 - val_loss: 3.8248 - val_auc: 0.8303
# Epoch 25/50
# 272/272 [==============================] - 128s 472ms/step - loss: 0.0457 - auc: 0.9998 - val_loss: 3.8609 - val_auc: 0.8294
# Epoch 26/50
# 272/272 [==============================] - 126s 465ms/step - loss: 0.0403 - auc: 1.0000 - val_loss: 4.0058 - val_auc: 0.8180
# Epoch 27/50
# 272/272 [==============================] - 120s 441ms/step - loss: 0.0384 - auc: 0.9999 - val_loss: 4.1065 - val_auc: 0.8179
# Epoch 28/50
# 272/272 [==============================] - 114s 419ms/step - loss: 0.0504 - auc: 0.9996 - val_loss: 4.1779 - val_auc: 0.8158
# Epoch 29/50
# 272/272 [==============================] - 126s 463ms/step - loss: 0.0554 - auc: 0.9998 - val_loss: 4.2771 - val_auc: 0.8114
# Epoch 30/50
# 272/272 [==============================] - 121s 444ms/step - loss: 0.0684 - auc: 0.9997 - val_loss: 4.4806 - val_auc: 0.8028
# Epoch 31/50
# 272/272 [==============================] - 118s 435ms/step - loss: 0.0563 - auc: 0.9998 - val_loss: 4.1289 - val_auc: 0.8148
# Epoch 32/50
# 272/272 [==============================] - 121s 446ms/step - loss: 0.0415 - auc: 0.9998 - val_loss: 4.3308 - val_auc: 0.8100
# Epoch 33/50
# 272/272 [==============================] - 118s 434ms/step - loss: 0.0445 - auc: 0.9998 - val_loss: 4.5393 - val_auc: 0.8041
# Epoch 34/50
# 272/272 [==============================] - 121s 444ms/step - loss: 0.0363 - auc: 0.9999 - val_loss: 4.2928 - val_auc: 0.8122
# Epoch 35/50
# 272/272 [==============================] - 118s 434ms/step - loss: 0.0394 - auc: 0.9998 - val_loss: 4.4492 - val_auc: 0.8059
# Epoch 36/50
# 272/272 [==============================] - 121s 445ms/step - loss: 0.0316 - auc: 0.9999 - val_loss: 4.3103 - val_auc: 0.8160
# Epoch 37/50
# 272/272 [==============================] - 121s 444ms/step - loss: 0.0427 - auc: 0.9998 - val_loss: 4.6176 - val_auc: 0.7941
# Epoch 38/50
# 272/272 [==============================] - 119s 437ms/step - loss: 0.0380 - auc: 0.9996 - val_loss: 4.4693 - val_auc: 0.8021
# Epoch 39/50
# 272/272 [==============================] - 117s 432ms/step - loss: 0.0339 - auc: 0.9998 - val_loss: 4.5647 - val_auc: 0.8050
# Epoch 40/50
# 272/272 [==============================] - 111s 407ms/step - loss: 0.0406 - auc: 0.9999 - val_loss: 4.7019 - val_auc: 0.8002
# Epoch 41/50
# 272/272 [==============================] - 118s 433ms/step - loss: 0.0504 - auc: 0.9995 - val_loss: 4.6599 - val_auc: 0.7984
# Epoch 42/50
# 272/272 [==============================] - 108s 396ms/step - loss: 0.0381 - auc: 0.9997 - val_loss: 4.8559 - val_auc: 0.7880
# Epoch 43/50
# 272/272 [==============================] - 116s 426ms/step - loss: 0.0475 - auc: 0.9997 - val_loss: 4.7051 - val_auc: 0.7985
# Epoch 44/50
# 272/272 [==============================] - 232s 855ms/step - loss: 0.0372 - auc: 0.9999 - val_loss: 4.9184 - val_auc: 0.7880
# Epoch 45/50
# 272/272 [==============================] - 248s 913ms/step - loss: 0.0378 - auc: 0.9999 - val_loss: 4.7663 - val_auc: 0.7979
# Epoch 46/50
# 272/272 [==============================] - 251s 923ms/step - loss: 0.0273 - auc: 0.9999 - val_loss: 4.6488 - val_auc: 0.8021
# Epoch 47/50
# 272/272 [==============================] - 250s 918ms/step - loss: 0.0378 - auc: 0.9996 - val_loss: 4.8557 - val_auc: 0.7908
# Epoch 48/50
# 272/272 [==============================] - 251s 922ms/step - loss: 0.0276 - auc: 0.9999 - val_loss: 4.7189 - val_auc: 0.7975
# Epoch 49/50
# 272/272 [==============================] - 257s 946ms/step - loss: 0.0213 - auc: 0.9999 - val_loss: 4.5823 - val_auc: 0.8035
# Epoch 50/50
# 272/272 [==============================] - 250s 919ms/step - loss: 0.0271 - auc: 0.9998 - val_loss: 4.8868 - val_auc: 0.7932
