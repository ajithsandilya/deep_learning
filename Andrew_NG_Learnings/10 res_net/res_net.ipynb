# %%
import tensorflow as tf
import numpy as np
import scipy.misc
from tensorflow.keras.applications.resnet_v2 import ResNet50V2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet_v2 import preprocess_input, decode_predictions
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Model, load_model
from resnets_utils import *
from tensorflow.keras.initializers import random_uniform, glorot_uniform, constant, identity
from tensorflow.python.framework.ops import EagerTensor
from matplotlib.pyplot import imshow

from test_utils import summary, comparator
import public_tests

# %matplotlib inline
# Out:
# 2023-11-27 10:52:33.771139: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-27 10:52:34.446478: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-27 10:52:34.446519: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-27 10:52:34.452524: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-27 10:52:34.844695: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-27 10:52:34.847248: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-27 10:52:38.230975: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# UNQ_C1
# GRADED FUNCTION: identity_block

def identity_block(X, f, filters, training=True, initializer=random_uniform):
    """
    Implementation of the identity block as defined in Figure 4
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    training -- True: Behave in training mode
                False: Behave in inference mode
    initializer -- to set up the initial weights of a layer. Equals to random uniform initializer
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    
    # Retrieve Filters
    F1, F2, F3 = filters
    # Save the input value. You'll need this later to add back to the main path. 
    X_shortcut = X
    cache = []
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = 1, strides = (1,1), padding = 'valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training = training) # Default axis
    X = Activation('relu')(X)
    
    ### START CODE HERE
    ## Second component of main path (≈3 lines)
    X = Conv2D(filters = F2, kernel_size = f,strides = (1, 1),padding='same',kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    X = Activation('relu')(X)

    ## Third component of main path (≈2 lines)
    X = Conv2D(filters = F3, kernel_size = 1, strides = (1, 1), padding='valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    
    ## Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    X = Add()([X_shortcut,X])
    X = Activation('relu')(X)
    ### END CODE HERE

    return X

# %%
np.random.seed(1)
X1 = np.ones((1, 4, 4, 3)) * -1
X2 = np.ones((1, 4, 4, 3)) * 1
X3 = np.ones((1, 4, 4, 3)) * 3

X = np.concatenate((X1, X2, X3), axis = 0).astype(np.float32)

A3 = identity_block(X, f=2, filters=[4, 4, 3],
                   initializer=lambda seed=0:constant(value=1),
                   training=False)
print('\033[1mWith training=False\033[0m\n')
A3np = A3.numpy()
print(np.around(A3.numpy()[:,(0,-1),:,:].mean(axis = 3), 5))
resume = A3np[:,(0,-1),:,:].mean(axis = 3)
print(resume[1, 1, 0])

print('\n\033[1mWith training=True\033[0m\n')
np.random.seed(1)
A4 = identity_block(X, f=2, filters=[3, 3, 3],
                   initializer=lambda seed=0:constant(value=1),
                   training=True)
print(np.around(A4.numpy()[:,(0,-1),:,:].mean(axis = 3), 5))

public_tests.identity_block_test(identity_block)
# Out:
# With training=False
#
# [[[  0.        0.        0.        0.     ]
#   [  0.        0.        0.        0.     ]]
#
#  [[192.71236 192.71236 192.71236  96.85619]
#   [ 96.85619  96.85619  96.85619  48.9281 ]]
#
#  [[578.1371  578.1371  578.1371  290.56854]
#   [290.56854 290.56854 290.56854 146.78427]]]
# 96.85619
#
# With training=True
#
# [[[0.      0.      0.      0.     ]
#   [0.      0.      0.      0.     ]]
#
#  [[0.40739 0.40739 0.40739 0.40739]
#   [0.40739 0.40739 0.40739 0.40739]]
#
#  [[4.99991 4.99991 4.99991 3.25948]
#   [3.25948 3.25948 3.25948 2.40739]]]
# All tests passed!

# %%
# UNQ_C2
# GRADED FUNCTION: convolutional_block

def convolutional_block(X, f, filters, s = 2, training=True, initializer=glorot_uniform):
    """
    Implementation of the convolutional block as defined in Figure 4
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    s -- Integer, specifying the stride to be used
    training -- True: Behave in training mode
                False: Behave in inference mode
    initializer -- to set up the initial weights of a layer. Equals to Glorot uniform initializer, 
                   also called Xavier uniform initializer.
    
    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    
    # First component of main path glorot_uniform(seed=0)
    X = Conv2D(filters = F1, kernel_size = 1, strides = (s, s), padding='valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    X = Activation('relu')(X)

    ### START CODE HERE
    
    ## Second component of main path (≈3 lines)
    X = Conv2D(filters = F2, kernel_size = f,strides = (1, 1),padding='same',kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    X = Activation('relu')(X)

    ## Third component of main path (≈2 lines)
    X = Conv2D(filters = F3, kernel_size = 1, strides = (1, 1), padding='valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    
    ##### SHORTCUT PATH ##### (≈2 lines)
    X_shortcut = Conv2D(filters = F3, kernel_size = 1, strides = (s, s), padding='valid', kernel_initializer = initializer(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3)(X_shortcut, training=training)
    
    ### END CODE HERE

    # Final step: Add shortcut value to main path (Use this order [X, X_shortcut]), and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
from outputs import convolutional_block_output1, convolutional_block_output2
np.random.seed(1)
#X = np.random.randn(3, 4, 4, 6).astype(np.float32)
X1 = np.ones((1, 4, 4, 3)) * -1
X2 = np.ones((1, 4, 4, 3)) * 1
X3 = np.ones((1, 4, 4, 3)) * 3

X = np.concatenate((X1, X2, X3), axis = 0).astype(np.float32)

A = convolutional_block(X, f = 2, filters = [2, 4, 6], training=False)

assert type(A) == EagerTensor, "Use only tensorflow and keras functions"
assert tuple(tf.shape(A).numpy()) == (3, 2, 2, 6), "Wrong shape."
assert np.allclose(A.numpy(), convolutional_block_output1), "Wrong values when training=False."
print(A[0])

B = convolutional_block(X, f = 2, filters = [2, 4, 6], training=True)
assert np.allclose(B.numpy(), convolutional_block_output2), "Wrong values when training=True."

print('\033[92mAll tests passed!')
# Out:
# tf.Tensor(
# [[[0.         0.66683817 0.         0.         0.888539   0.5274254 ]
#   [0.         0.65053666 0.         0.         0.8959285  0.49965227]]
#
#  [[0.         0.6312079  0.         0.         0.86362475 0.47643146]
#   [0.         0.56883204 0.         0.         0.8553412  0.417093  ]]], shape=(2, 2, 6), dtype=float32)
# All tests passed!

# %%
# UNQ_C3
# GRADED FUNCTION: ResNet50

def ResNet50(input_shape = (64, 64, 3), classes = 6):
    """
    Stage-wise implementation of the architecture of the popular ResNet50:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> FLATTEN -> DENSE 

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    
    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3)(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], s = 1)
    X = identity_block(X, 3, [64, 64, 256])
    X = identity_block(X, 3, [64, 64, 256])

    ### START CODE HERE
    
    ## Stage 3 (≈4 lines)
    X = convolutional_block(X, f = 3, filters = [128,128,512], s = 2)
    X = identity_block(X, 3,  [128,128,512])
    X = identity_block(X, 3,  [128,128,512])
    X = identity_block(X, 3,  [128,128,512])
    
    ## Stage 4 (≈6 lines)
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], s = 2)
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])

    ## Stage 5 (≈3 lines)
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], s = 2)
    X = identity_block(X, 3, [512, 512, 2048])
    X = identity_block(X, 3, [512, 512, 2048])

    ## AVGPOOL (≈1 line). Use "X = AveragePooling2D(...)(X)"
    X = AveragePooling2D((2, 2))(X)
    
    ### END CODE HERE

    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X)

    return model

# %%
model = ResNet50(input_shape = (64, 64, 3), classes = 6)
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  zero_padding2d (ZeroPaddin  (None, 70, 70, 3)            0         ['input_1[0][0]']
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 32, 32, 64)           9472      ['zero_padding2d[0][0]']
#
#  batch_normalization_44 (Ba  (None, 32, 32, 64)           256       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 32, 32, 64)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 64)           0         ['activation_42[0][0]']
#  D)
#
#  conv2d_45 (Conv2D)          (None, 15, 15, 64)           4160      ['max_pooling2d[0][0]']
#
#  batch_normalization_45 (Ba  (None, 15, 15, 64)           256       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 15, 15, 64)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 15, 15, 64)           36928     ['activation_43[0][0]']
#
#  batch_normalization_46 (Ba  (None, 15, 15, 64)           256       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 15, 15, 64)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 15, 15, 256)          16640     ['activation_44[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 15, 15, 256)          16640     ['max_pooling2d[0][0]']
#
#  batch_normalization_47 (Ba  (None, 15, 15, 256)          1024      ['conv2d_47[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 15, 15, 256)          1024      ['conv2d_48[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 15, 15, 256)          0         ['batch_normalization_47[0][0]
#                                                                     ',
#                                                                      'batch_normalization_48[0][0]
#                                                                     ']
#
#  activation_45 (Activation)  (None, 15, 15, 256)          0         ['add_14[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 15, 15, 64)           16448     ['activation_45[0][0]']
#
#  batch_normalization_49 (Ba  (None, 15, 15, 64)           256       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 15, 15, 64)           0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_50 (Conv2D)          (None, 15, 15, 64)           36928     ['activation_46[0][0]']
#
#  batch_normalization_50 (Ba  (None, 15, 15, 64)           256       ['conv2d_50[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 15, 15, 64)           0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 15, 15, 256)          16640     ['activation_47[0][0]']
#
#  batch_normalization_51 (Ba  (None, 15, 15, 256)          1024      ['conv2d_51[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 15, 15, 256)          0         ['activation_45[0][0]',
#                                                                      'batch_normalization_51[0][0]
#                                                                     ']
#
#  activation_48 (Activation)  (None, 15, 15, 256)          0         ['add_15[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 15, 15, 64)           16448     ['activation_48[0][0]']
#
#  batch_normalization_52 (Ba  (None, 15, 15, 64)           256       ['conv2d_52[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 15, 15, 64)           0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  conv2d_53 (Conv2D)          (None, 15, 15, 64)           36928     ['activation_49[0][0]']
#
#  batch_normalization_53 (Ba  (None, 15, 15, 64)           256       ['conv2d_53[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 15, 15, 64)           0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 15, 15, 256)          16640     ['activation_50[0][0]']
#
#  batch_normalization_54 (Ba  (None, 15, 15, 256)          1024      ['conv2d_54[0][0]']
#  tchNormalization)
#
#  add_16 (Add)                (None, 15, 15, 256)          0         ['activation_48[0][0]',
#                                                                      'batch_normalization_54[0][0]
#                                                                     ']
#
#  activation_51 (Activation)  (None, 15, 15, 256)          0         ['add_16[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 8, 8, 128)            32896     ['activation_51[0][0]']
#
#  batch_normalization_55 (Ba  (None, 8, 8, 128)            512       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_56 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_52[0][0]']
#
#  batch_normalization_56 (Ba  (None, 8, 8, 128)            512       ['conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  conv2d_57 (Conv2D)          (None, 8, 8, 512)            66048     ['activation_53[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 8, 8, 512)            131584    ['activation_51[0][0]']
#
#  batch_normalization_57 (Ba  (None, 8, 8, 512)            2048      ['conv2d_57[0][0]']
#  tchNormalization)
#
#  batch_normalization_58 (Ba  (None, 8, 8, 512)            2048      ['conv2d_58[0][0]']
#  tchNormalization)
#
#  add_17 (Add)                (None, 8, 8, 512)            0         ['batch_normalization_57[0][0]
#                                                                     ',
#                                                                      'batch_normalization_58[0][0]
#                                                                     ']
#
#  activation_54 (Activation)  (None, 8, 8, 512)            0         ['add_17[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 8, 8, 128)            65664     ['activation_54[0][0]']
#
#  batch_normalization_59 (Ba  (None, 8, 8, 128)            512       ['conv2d_59[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  conv2d_60 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_55[0][0]']
#
#  batch_normalization_60 (Ba  (None, 8, 8, 128)            512       ['conv2d_60[0][0]']
#  tchNormalization)
#
#  activation_56 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  conv2d_61 (Conv2D)          (None, 8, 8, 512)            66048     ['activation_56[0][0]']
#
#  batch_normalization_61 (Ba  (None, 8, 8, 512)            2048      ['conv2d_61[0][0]']
#  tchNormalization)
#
#  add_18 (Add)                (None, 8, 8, 512)            0         ['activation_54[0][0]',
#                                                                      'batch_normalization_61[0][0]
#                                                                     ']
#
#  activation_57 (Activation)  (None, 8, 8, 512)            0         ['add_18[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 8, 8, 128)            65664     ['activation_57[0][0]']
#
#  batch_normalization_62 (Ba  (None, 8, 8, 128)            512       ['conv2d_62[0][0]']
#  tchNormalization)
#
#  activation_58 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  conv2d_63 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_58[0][0]']
#
#  batch_normalization_63 (Ba  (None, 8, 8, 128)            512       ['conv2d_63[0][0]']
#  tchNormalization)
#
#  activation_59 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  conv2d_64 (Conv2D)          (None, 8, 8, 512)            66048     ['activation_59[0][0]']
#
#  batch_normalization_64 (Ba  (None, 8, 8, 512)            2048      ['conv2d_64[0][0]']
#  tchNormalization)
#
#  add_19 (Add)                (None, 8, 8, 512)            0         ['activation_57[0][0]',
#                                                                      'batch_normalization_64[0][0]
#                                                                     ']
#
#  activation_60 (Activation)  (None, 8, 8, 512)            0         ['add_19[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 8, 8, 128)            65664     ['activation_60[0][0]']
#
#  batch_normalization_65 (Ba  (None, 8, 8, 128)            512       ['conv2d_65[0][0]']
#  tchNormalization)
#
#  activation_61 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  conv2d_66 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_61[0][0]']
#
#  batch_normalization_66 (Ba  (None, 8, 8, 128)            512       ['conv2d_66[0][0]']
#  tchNormalization)
#
#  activation_62 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  conv2d_67 (Conv2D)          (None, 8, 8, 512)            66048     ['activation_62[0][0]']
#
#  batch_normalization_67 (Ba  (None, 8, 8, 512)            2048      ['conv2d_67[0][0]']
#  tchNormalization)
#
#  add_20 (Add)                (None, 8, 8, 512)            0         ['activation_60[0][0]',
#                                                                      'batch_normalization_67[0][0]
#                                                                     ']
#
#  activation_63 (Activation)  (None, 8, 8, 512)            0         ['add_20[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 4, 4, 256)            131328    ['activation_63[0][0]']
#
#  batch_normalization_68 (Ba  (None, 4, 4, 256)            1024      ['conv2d_68[0][0]']
#  tchNormalization)
#
#  activation_64 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  conv2d_69 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_64[0][0]']
#
#  batch_normalization_69 (Ba  (None, 4, 4, 256)            1024      ['conv2d_69[0][0]']
#  tchNormalization)
#
#  activation_65 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  conv2d_70 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_65[0][0]']
#
#  conv2d_71 (Conv2D)          (None, 4, 4, 1024)           525312    ['activation_63[0][0]']
#
#  batch_normalization_70 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_70[0][0]']
#  tchNormalization)
#
#  batch_normalization_71 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_71[0][0]']
#  tchNormalization)
#
#  add_21 (Add)                (None, 4, 4, 1024)           0         ['batch_normalization_70[0][0]
#                                                                     ',
#                                                                      'batch_normalization_71[0][0]
#                                                                     ']
#
#  activation_66 (Activation)  (None, 4, 4, 1024)           0         ['add_21[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_66[0][0]']
#
#  batch_normalization_72 (Ba  (None, 4, 4, 256)            1024      ['conv2d_72[0][0]']
#  tchNormalization)
#
#  activation_67 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  conv2d_73 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_67[0][0]']
#
#  batch_normalization_73 (Ba  (None, 4, 4, 256)            1024      ['conv2d_73[0][0]']
#  tchNormalization)
#
#  activation_68 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  conv2d_74 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_68[0][0]']
#
#  batch_normalization_74 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_74[0][0]']
#  tchNormalization)
#
#  add_22 (Add)                (None, 4, 4, 1024)           0         ['activation_66[0][0]',
#                                                                      'batch_normalization_74[0][0]
#                                                                     ']
#
#  activation_69 (Activation)  (None, 4, 4, 1024)           0         ['add_22[0][0]']
#
#  conv2d_75 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_69[0][0]']
#
#  batch_normalization_75 (Ba  (None, 4, 4, 256)            1024      ['conv2d_75[0][0]']
#  tchNormalization)
#
#  activation_70 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_75[0][0]
#                                                                     ']
#
#  conv2d_76 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_70[0][0]']
#
#  batch_normalization_76 (Ba  (None, 4, 4, 256)            1024      ['conv2d_76[0][0]']
#  tchNormalization)
#
#  activation_71 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  conv2d_77 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_71[0][0]']
#
#  batch_normalization_77 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_77[0][0]']
#  tchNormalization)
#
#  add_23 (Add)                (None, 4, 4, 1024)           0         ['activation_69[0][0]',
#                                                                      'batch_normalization_77[0][0]
#                                                                     ']
#
#  activation_72 (Activation)  (None, 4, 4, 1024)           0         ['add_23[0][0]']
#
#  conv2d_78 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_72[0][0]']
#
#  batch_normalization_78 (Ba  (None, 4, 4, 256)            1024      ['conv2d_78[0][0]']
#  tchNormalization)
#
#  activation_73 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  conv2d_79 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_73[0][0]']
#
#  batch_normalization_79 (Ba  (None, 4, 4, 256)            1024      ['conv2d_79[0][0]']
#  tchNormalization)
#
#  activation_74 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  conv2d_80 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_74[0][0]']
#
#  batch_normalization_80 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_80[0][0]']
#  tchNormalization)
#
#  add_24 (Add)                (None, 4, 4, 1024)           0         ['activation_72[0][0]',
#                                                                      'batch_normalization_80[0][0]
#                                                                     ']
#
#  activation_75 (Activation)  (None, 4, 4, 1024)           0         ['add_24[0][0]']
#
#  conv2d_81 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_75[0][0]']
#
#  batch_normalization_81 (Ba  (None, 4, 4, 256)            1024      ['conv2d_81[0][0]']
#  tchNormalization)
#
#  activation_76 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  conv2d_82 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_76[0][0]']
#
#  batch_normalization_82 (Ba  (None, 4, 4, 256)            1024      ['conv2d_82[0][0]']
#  tchNormalization)
#
#  activation_77 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  conv2d_83 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_77[0][0]']
#
#  batch_normalization_83 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_83[0][0]']
#  tchNormalization)
#
#  add_25 (Add)                (None, 4, 4, 1024)           0         ['activation_75[0][0]',
#                                                                      'batch_normalization_83[0][0]
#                                                                     ']
#
#  activation_78 (Activation)  (None, 4, 4, 1024)           0         ['add_25[0][0]']
#
#  conv2d_84 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_78[0][0]']
#
#  batch_normalization_84 (Ba  (None, 4, 4, 256)            1024      ['conv2d_84[0][0]']
#  tchNormalization)
#
#  activation_79 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  conv2d_85 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_79[0][0]']
#
#  batch_normalization_85 (Ba  (None, 4, 4, 256)            1024      ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_80 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_80[0][0]']
#
#  batch_normalization_86 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_86[0][0]']
#  tchNormalization)
#
#  add_26 (Add)                (None, 4, 4, 1024)           0         ['activation_78[0][0]',
#                                                                      'batch_normalization_86[0][0]
#                                                                     ']
#
#  activation_81 (Activation)  (None, 4, 4, 1024)           0         ['add_26[0][0]']
#
#  conv2d_87 (Conv2D)          (None, 2, 2, 512)            524800    ['activation_81[0][0]']
#
#  batch_normalization_87 (Ba  (None, 2, 2, 512)            2048      ['conv2d_87[0][0]']
#  tchNormalization)
#
#  activation_82 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  conv2d_88 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_82[0][0]']
#
#  batch_normalization_88 (Ba  (None, 2, 2, 512)            2048      ['conv2d_88[0][0]']
#  tchNormalization)
#
#  activation_83 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  conv2d_89 (Conv2D)          (None, 2, 2, 2048)           1050624   ['activation_83[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 2, 2, 2048)           2099200   ['activation_81[0][0]']
#
#  batch_normalization_89 (Ba  (None, 2, 2, 2048)           8192      ['conv2d_89[0][0]']
#  tchNormalization)
#
#  batch_normalization_90 (Ba  (None, 2, 2, 2048)           8192      ['conv2d_90[0][0]']
#  tchNormalization)
#
#  add_27 (Add)                (None, 2, 2, 2048)           0         ['batch_normalization_89[0][0]
#                                                                     ',
#                                                                      'batch_normalization_90[0][0]
#                                                                     ']
#
#  activation_84 (Activation)  (None, 2, 2, 2048)           0         ['add_27[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 2, 2, 512)            1049088   ['activation_84[0][0]']
#
#  batch_normalization_91 (Ba  (None, 2, 2, 512)            2048      ['conv2d_91[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  conv2d_92 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_85[0][0]']
#
#  batch_normalization_92 (Ba  (None, 2, 2, 512)            2048      ['conv2d_92[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  conv2d_93 (Conv2D)          (None, 2, 2, 2048)           1050624   ['activation_86[0][0]']
#
#  batch_normalization_93 (Ba  (None, 2, 2, 2048)           8192      ['conv2d_93[0][0]']
#  tchNormalization)
#
#  add_28 (Add)                (None, 2, 2, 2048)           0         ['activation_84[0][0]',
#                                                                      'batch_normalization_93[0][0]
#                                                                     ']
#
#  activation_87 (Activation)  (None, 2, 2, 2048)           0         ['add_28[0][0]']
#
#  conv2d_94 (Conv2D)          (None, 2, 2, 512)            1049088   ['activation_87[0][0]']
#
#  batch_normalization_94 (Ba  (None, 2, 2, 512)            2048      ['conv2d_94[0][0]']
#  tchNormalization)
#
#  activation_88 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_95 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_88[0][0]']
#
#  batch_normalization_95 (Ba  (None, 2, 2, 512)            2048      ['conv2d_95[0][0]']
#  tchNormalization)
#
#  activation_89 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  conv2d_96 (Conv2D)          (None, 2, 2, 2048)           1050624   ['activation_89[0][0]']
#
#  batch_normalization_96 (Ba  (None, 2, 2, 2048)           8192      ['conv2d_96[0][0]']
#  tchNormalization)
#
#  add_29 (Add)                (None, 2, 2, 2048)           0         ['activation_87[0][0]',
#                                                                      'batch_normalization_96[0][0]
#                                                                     ']
#
#  activation_90 (Activation)  (None, 2, 2, 2048)           0         ['add_29[0][0]']
#
#  average_pooling2d (Average  (None, 1, 1, 2048)           0         ['activation_90[0][0]']
#  Pooling2D)
#
#  flatten (Flatten)           (None, 2048)                 0         ['average_pooling2d[0][0]']
#
#  dense (Dense)               (None, 6)                    12294     ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23600006 (90.03 MB)
# Trainable params: 23546886 (89.82 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________
# None

# %%
from outputs import ResNet50_summary

model = ResNet50(input_shape = (64, 64, 3), classes = 6)

comparator(summary(model), ResNet50_summary)
# Out:
# All tests passed!

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# Normalize image vectors
X_train = X_train_orig / 255.
X_test = X_test_orig / 255.

# Convert training and test labels to one hot matrices
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %%
model.fit(X_train, Y_train, epochs = 10, batch_size = 32)
# Out:
# Epoch 1/10
# 34/34 [==============================] - 77s 2s/step - loss: 1.6555 - accuracy: 0.4926
# Epoch 2/10
# 34/34 [==============================] - 61s 2s/step - loss: 0.7106 - accuracy: 0.7565
# Epoch 3/10
# 34/34 [==============================] - 63s 2s/step - loss: 0.4152 - accuracy: 0.8759
# Epoch 4/10
# 34/34 [==============================] - 65s 2s/step - loss: 0.2217 - accuracy: 0.9259
# Epoch 5/10
# 34/34 [==============================] - 61s 2s/step - loss: 0.2875 - accuracy: 0.9148
# Epoch 6/10
# 34/34 [==============================] - 61s 2s/step - loss: 0.2824 - accuracy: 0.9083
# Epoch 7/10
# 34/34 [==============================] - 59s 2s/step - loss: 0.1678 - accuracy: 0.9500
# Epoch 8/10
# 34/34 [==============================] - 59s 2s/step - loss: 0.2658 - accuracy: 0.9213
# Epoch 9/10
# 34/34 [==============================] - 59s 2s/step - loss: 0.1767 - accuracy: 0.9435
# Epoch 10/10
# 34/34 [==============================] - 59s 2s/step - loss: 0.2083 - accuracy: 0.9454

# %%
preds = model.evaluate(X_test, Y_test)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 4/4 [==============================] - 3s 292ms/step - loss: 0.5076 - accuracy: 0.8250
# Loss = 0.5075992345809937
# Test Accuracy = 0.824999988079071
